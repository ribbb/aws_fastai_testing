# %%
from fastai import *
from fastai.vision import *

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
print("hello world  - conda_pytorch_p36")
# Out:
# hello world  - conda_pytorch_p36

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /home/ec2-user/SageMaker/aws_fastai_testing/.git/

# %%
# !git add .
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-60-7f9dd92843a7> in <module>()
# ----> 1 get_ipython().system('git add .')
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/IPython/core/interactiveshell.py in system_piped(self, cmd)
#    2259         # a non-None value would trigger :func:`sys.displayhook` calls.
#    2260         # Instead, we store the exit_code in user_ns.
# -> 2261         self.user_ns['_exit_code'] = system(self.var_expand(cmd, depth=1))
#    2262
#    2263     def system_raw(self, cmd):
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     154                 child = pexpect.spawnb(self.sh, args=['-c', cmd]) # Pexpect-U
#     155             else:
# --> 156                 child = pexpect.spawn(self.sh, args=['-c', cmd])  # Vanilla Pexpect
# ...

# %%
# !git commit -m "test"
# Out:
# [master (root-commit) 87d7826] test
#  Committer: EC2 Default User <ec2-user@ip-172-16-74-207.us-east-2.compute.internal>
# Your name and email address were configured automatically based
# on your username and hostname. Please check that they are accurate.
# You can suppress this message by setting them explicitly:
#
#     git config --global user.name "Your Name"
#     git config --global user.email you@example.com
#
# After doing this, you may fix the identity used for this commit with:
#
#     git commit --amend --reset-author
#
#  2 files changed, 103 insertions(+)
#  create mode 100644 .ipynb_checkpoints/Untitled-checkpoint.ipynb
#  create mode 100644 Untitled.ipynb

# %%
# !git push origin master
# Out:
# Counting objects: 5, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 963 bytes | 963.00 KiB/s, done.
# Total 5 (delta 0), reused 0 (delta 0)
# To https://github.com/ribbb/aws_fastai_testing
#  * [new branch]      master -> master

# %%
path = untar_data(URLs.PETS); path
# Out:
# ...
# PosixPath('/home/ec2-user/.fastai/data/oxford-iiit-pet')

# %%
path.ls()
# Out:
# [PosixPath('/home/ec2-user/.fastai/data/oxford-iiit-pet/images'),
#  PosixPath('/home/ec2-user/.fastai/data/oxford-iiit-pet/annotations')]

# %%
path_images = path/"images"
path_annos = path/"annotations"

# %%
image_names = get_image_files(path_images)

# %%
image_names[:5]
# Out:
# [PosixPath('/home/ec2-user/.fastai/data/oxford-iiit-pet/images/english_setter_100.jpg'),
#  PosixPath('/home/ec2-user/.fastai/data/oxford-iiit-pet/images/British_Shorthair_88.jpg'),
#  PosixPath('/home/ec2-user/.fastai/data/oxford-iiit-pet/images/Abyssinian_43.jpg'),
#  PosixPath('/home/ec2-user/.fastai/data/oxford-iiit-pet/images/beagle_198.jpg'),
#  PosixPath('/home/ec2-user/.fastai/data/oxford-iiit-pet/images/great_pyrenees_133.jpg')]

# %%
np.random.seed(2)
pat = r'/([^/]+)_\d+.jpg$'
data = ImageDataBunch.from_name_re(path_images, image_names, pat, ds_tfms=get_transforms(), size=224)

# %%
data.normalize(imagenet_stats)
# Out:
# ImageDataBunch;
#
# Train: LabelList (5912 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# english_setter,British_Shorthair,Abyssinian,saint_bernard,beagle
# Path: /home/ec2-user/.fastai/data/oxford-iiit-pet/images;
#
# Valid: LabelList (1478 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# Egyptian_Mau,miniature_pinscher,english_cocker_spaniel,staffordshire_bull_terrier,samoyed
# Path: /home/ec2-user/.fastai/data/oxford-iiit-pet/images;
#
# Test: None

# %%
data.show_batch(rows=3, figsize=(7,6))

# %%
print(data.classes, data.c)
# Out:
# ['Abyssinian', 'Bengal', 'Birman', 'Bombay', 'British_Shorthair', 'Egyptian_Mau', 'Maine_Coon', 'Persian', 'Ragdoll', 'Russian_Blue', 'Siamese', 'Sphynx', 'american_bulldog', 'american_pit_bull_terrier', 'basset_hound', 'beagle', 'boxer', 'chihuahua', 'english_cocker_spaniel', 'english_setter', 'german_shorthaired', 'great_pyrenees', 'havanese', 'japanese_chin', 'keeshond', 'leonberger', 'miniature_pinscher', 'newfoundland', 'pomeranian', 'pug', 'saint_bernard', 'samoyed', 'scottish_terrier', 'shiba_inu', 'staffordshire_bull_terrier', 'wheaten_terrier', 'yorkshire_terrier'] 37

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /home/ec2-user/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# ...

# %%
from sagemaker.pytorch import PyTorch
def test_function(learn):
    learn.fit_one_cycle(1)

# %%
'''
pets_estimator = PyTorch(entry_point=test_function(learn),
                         base_job_name='fastai-pets',
                         role=role,
                         framework_version='1.0.0',
                         train_instance_count=1,
                         train_instance_type='ml.p2.xlarge')
'''
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
# ...
